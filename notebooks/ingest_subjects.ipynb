# %%
from labdata.schema import Subject
from datetime import datetime
import pandas as pd

# %%
def date_from_string(date_str):
    """return a datetime.date object from a string in the following format: YYYY-MM-DD

    Args:
        date_str (str): date string to be converted

    Returns:
        datetime.date: string converted to a datetime.date object
    """
    return datetime.strptime(date_str, "%Y-%m-%d").date()

# %%
mice_to_add = [
    dict(
        subject_name="GRB050",
        subject_dob=date_from_string("2025-11-28"),
        subject_sex="M",
        strain_name="C57BL/6J",
        user_name="rojasbowe",
    ),
    dict(
        subject_name="GRB051",
        subject_dob=date_from_string("2025-11-28"),
        subject_sex="M",
        strain_name="C57BL/6J",
        user_name="rojasbowe",
    ),
    dict(
        subject_name="GRB052",
        subject_dob=date_from_string("2025-11-28"),
        subject_sex="M",
        strain_name="C57BL/6J",
        user_name="rojasbowe",
    ),
    dict(
        subject_name="GRB053",
        subject_dob=date_from_string("2025-11-28"),
        subject_sex="M",
        strain_name="C57BL/6J",
        user_name="rojasbowe",
    ),
    dict(
        subject_name="GRB054",
        subject_dob=date_from_string("2025-11-26"),
        subject_sex="F",
        strain_name="C57BL/6J",
        user_name="rojasbowe",
    ),
    dict(
        subject_name="GRB055",
        subject_dob=date_from_string("2025-11-26"),
        subject_sex="F",
        strain_name="C57BL/6J",
        user_name="rojasbowe",
    ),
    dict(
        subject_name="GRB056",
        subject_dob=date_from_string("2025-11-26"),
        subject_sex="F",
        strain_name="C57BL/6J",
        user_name="rojasbowe",
    ),
    dict(
        subject_name="GRB057",
        subject_dob=date_from_string("2025-11-26"),
        subject_sex="F",
        strain_name="C57BL/6J",
        user_name="rojasbowe",
    ),
    dict(
        subject_name="GRB058",
        subject_dob=date_from_string("2025-11-28"),
        subject_sex="M",
        strain_name="C57BL/6J",
        user_name="rojasbowe",
    ),
    dict(
        subject_name="GRB059",
        subject_dob=date_from_string("2025-11-28"),
        subject_sex="M",
        strain_name="C57BL/6J",
        user_name="rojasbowe",
    ),
]
Subject.insert(mice_to_add, skip_duplicates=True)

# %%
pd.DataFrame(Subject())[::-1]
